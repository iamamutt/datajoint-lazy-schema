# %% [markdown]
# # Problem 3
#
# Relying on a user provided function that exists in an imported module/make function.

# %%
import datajoint as dj

dj.Schema("my_custom_workflow_child").drop(force=True)
dj.Schema("my_custom_workflow_parent").drop(force=True)
# Out:
# Connecting root@localhost:3306

# %% [markdown]
# Import the content from file `src/my_dj_package/custom_pipeline.py`.

# %%
from my_dj_package.custom_pipeline import Child, Parent, Sibling
dj.list_schemas()
# Out:
# ['my_custom_workflow_child',
#  'my_custom_workflow_parent',
#  'mysql',
#  'performance_schema',
#  'sys']

# %% [markdown]
# Add manual entries, then populate downstream content.

# %%
Parent.insert1({"field": "parent"})
Sibling.insert1({"field2": "sibling"})
Child.populate()

# %% [markdown]
# The path uses the custom function defined in `custom_pipeline.py` instead of the function defined in `src/datajoint_extension/pipeline/child.py`

# %%
Child()
# Out:
# *field     *field2     *path
# +--------+ +---------+ +------------+
# parent     sibling     some/different
#  (Total: 1)

# %% [markdown]
# ### Content of `src/my_dj_package/custom_pipeline.py`

# %%
from datajoint_extension.pipeline.child import some_schema_requirement
from datajoint_extension.tables import Child, Parent, Sibling


# register the below function to be called when the function in
# datajoint_extension.pipeline.child has None as the input type
@some_schema_requirement.register
def _some_schema_requirement(obj: None):
    return "some/different/path"
